# %%
from datetime import datetime, timezone
from uuid import uuid4

import pandas as pd
import tqdm

# %% [markdown]
# ## Habit Format

# %%
# The exported CSV from Habitude does not contain a header, so we define it here.
# Some columns are still unknown though.

header = [str(i) for i in range(12)]
header[0] = "id"
header[1] = "name"
# h[2] = "is_progressive?"  # or might be the target value for progressive habits
header[3] = "description"
header[4] = "color_id"
header[5] = "creation_date"
header[6] = (
    "goal"  # 0 means daily; 2:X means X times per week; there are likely further formats
)
# h[7] = "some_str"
# h[8] = "some_float"
header[9] = "unit"
header[10] = (
    "date_quantity"  # "-" separated list of "{YYYYMMDD}:{quantity}" (unordered by the way)
)
# h[11] = "exceedable?"  # or target_quantity for progressive habits?


habits_df = pd.read_csv("./habitude.csv", header=None, names=header)
# Sort by name
habits_df = habits_df.sort_values(by=["name"])
habits_df
# Out:
#     id                               name  2  \
# 0    1               01. Film/Series/Game  0
# 15  24                        02. Allergy  0
# 1    2                          03. Write  0
# 18  27                    04. Cutsie Book  0
# 17  26                           05. VitD  0
# 3    4                        07. Finance  0
# 4    5                          08. Music  0
# 6    7                           09. Read  0
# 2    3                          10. Sport  0
# 5    6                            11. NoX  0
# 16  25                            12. Sex  0
# 7    8                         13. NoCaff  0
# 19  28                          13.1 Caff  1
# 14  23                      14. VeggieDay  0
# 8   11               15. Photography/Edit  0
# 9   12  16. Take a walk and free the mind  0
# 10  13     17. Reflection/Personal Growth  0
# 12  21                       19. Headache  0
# 11  20                            20. Ibu  0
# 13  22                        21. Alcohol  0
#
#                               description  color_id             creation_date  \
# 0                                     NaN         3    2019-02-21-0:0:00.0000
# 15                                    NaN        17    2022-05-11-0:0:00.0000
# 1              Hast du heute geschrieben?         3    2018-10-10-0:0:00.0000
# 18                                    NaN         8    2023-01-14-0:0:00.0000
# 17                                    NaN        16    2022-09-13-0:0:00.0000
# 3                                     NaN         5    2019-03-17-0:0:00.0000
# 4            Hast du heute Musik gemacht?         4    2018-10-10-0:0:00.0000
# 6         Hast du heute gelesen? (30min+)        13    2018-10-10-0:0:00.0000
# 2                                     NaN         6    2019-02-23-0:0:00.0000
# 5          Did you resist a specific urge        14     2018-10-2-0:0:00.0000
# 16                                    NaN        17    2022-09-17-0:0:00.0000
# 7   Hast du heute auf Koffein verzichtet?        12    2018-10-11-0:0:00.0000
# 19                                    NaN        11  2023-09-11-14:54:56.4340
# 14                                    NaN         8    2022-01-12-0:0:00.0000
# 8                                     NaN        15    2019-08-22-0:0:00.0000
# 9                                     NaN        15    2019-10-21-0:0:00.0000
# 10  At least an hour of active reflection        15    2020-01-12-0:0:00.0000
# 12                                    NaN         8     2021-12-6-0:0:00.0000
# 11                                    NaN         0    2021-10-21-0:0:00.0000
# 13                                    NaN         8    2021-12-10-0:0:00.0000
#
#    goal   7    8 unit                                      date_quantity  11
# 0   2:4 NaN  1.0  NaN  20210329:1-20220103:1-20201008:1-20210314:1-20...   0
# 15    0 NaN  1.0  NaN  20220521:1-20250613:1-20220611:1-20230527:1-20...   0
# 1     0 NaN  1.0  NaN  20220103:1-20230629:1-20181021:1-20220507:1-20...   0
# 18    0 NaN  1.0  NaN  20230308:1-20230312:1-20230313:1-20230119:1-20...   0
# 17    0 NaN  1.0  NaN  20230108:1-20230227:1-20230204:1-20221223:1-20...   0
# 3   2:1 NaN  1.0  NaN  20220521:1-20211202:1-20230108:1-20190823:1-20...   0
# 4     0 NaN  1.0  NaN  20190209:1-20190607:1-20190911:1-20240811:1-20...   0
# 6     0 NaN  1.0  NaN  20190209:1-20240714:1-20220626:1-20231212:1-20...   0
# 2   2:2 NaN  1.0  NaN  20200105:1-20191026:1-20210202:1-20200913:1-20...   0
# 5   2:5 NaN  1.0  NaN  20191120:1-20230114:1-20190326:1-20221228:1-20...   0
# 16  2:1 NaN  1.0  NaN  20230625:1-20240607:1-20230213:1-20230312:1-20...   0
# 7     0 NaN  1.0  NaN  20181128:1-20241116:1-20181119:1-20190411:1-20...   0
# 19    0 NaN  1.0  Cup                   20230912:1-20230911:3-20230913:1   1
# 14    0 NaN  1.0  NaN  20230227:1-20230527:1-20220409:1-20220323:1-20...   0
# 8   2:1 NaN  1.0  NaN  20200329:1-20190823:1-20201122:1-20201113:1-20...   0
# 9     0 NaN  1.0  NaN  20210913:1-20220618:1-20200106:1-20211022:1-20...   0
# 10  2:1 NaN  1.0  NaN  20201227:1-20201026:1-20220920:1-20200613:1-20...   0
# 12    0 NaN  1.0  NaN  20220221:1-20220630:1-20230709:1-20241224:1-20...   0
# 11    0 NaN  1.0  NaN  20241115:1-20211022:1-20240224:1-20240710:1-20...   0
# 13    0 NaN  1.0  NaN  20220521:1-20220611:1-20240724:1-20220603:1-20...   0

# %%
header
# Out:
# ['id',
#  'name',
#  '2',
#  'description',
#  'color_id',
#  'creation_date',
#  'goal',
#  '7',
#  '8',
#  'unit',
#  'date_quantity',
#  '11']

# %%
def parse_date_to_quantity(habit_row):
    return {
        date: int(qty)
        for date, qty in (
            entry.split(":") for entry in sorted(habit_row["date_quantity"].split("-"))
        )
    }


parse_date_to_quantity(habits_df.iloc[0])
# Out:
# {'20190222': 1,
#  '20190223': 1,
#  '20190226': 1,
#  '20190227': 1,
#  '20190301': 1,
#  '20190307': 1,
#  '20190309': 1,
#  '20190316': 1,
#  '20190320': 1,
#  '20190322': 1,
#  '20190323': 1,
#  '20190325': 1,
#  '20190327': 1,
#  '20190328': 1,
#  '20190401': 1,
#  '20190402': 1,
#  '20190403': 1,
#  '20190404': 1,
#  '20190406': 1,
#  '20190407': 1,
#  '20190408': 1,
#  '20190409': 1,
#  '20190410': 1,
#  '20190412': 1,
#  '20190413': 1,
#  '20190414': 1,
#  '20190415': 1,
#  '20190417': 1,
#  '20190419': 1,
#  '20190420': 1,
#  '20190421': 1,
#  '20190423': 1,
#  '20190424': 1,
#  '20190426': 1,
#  '20190429': 1,
#  '20190430': 1,
#  '20190502': 1,
#  '20190503': 1,
#  '20190506': 1,
#  '20190507': 1,
#  '20190508': 1,
#  '20190510': 1,
#  '20190512': 1,
#  '20190513': 1,
#  '20190514': 1,
#  '20190515': 1,
#  '20190516': 1,
#  '20190517': 1,
#  '20190519': 1,
#  '20190520': 1,
#  '20190524': 1,
#  '20231220': 1,
#  '20231221': 1,
#  '20231223': 1,
#  '20231225': 1,
#  '20231227': 1,
#  '20231228': 1,
#  '20231230': 1,
#  '20231231': 1,
#  '20240102': 1,
#  '20240103': 1,
#  '20240104': 1,
#  '20240106': 1,
#  '20240107': 1,
#  '20240113': 1,
#  '20240114': 1,
#  '20240121': 1,
#  '20240122': 1,
#  '20240123': 1,
#  '20240124': 1,
#  '20240128': 1,
#  '20240130': 1,
#  '20240201': 1,
#  '20240203': 1,
#  '20240205': 1,
#  '20240215': 1,
#  '20240218': 1,
#  '20240219': 1,
#  '20240220': 1,
#  '20240221': 1,
#  '20240222': 1,
#  '20240224': 1,
#  '20240225': 1,
#  '20240226': 1,
#  '20240227': 1,
#  '20240228': 1,
#  '20240229': 1,
#  '20240302': 1,
#  '20240303': 1,
#  '20240304': 1,
#  '20240309': 1,
#  '20240316': 1,
#  '20240317': 1,
#  '20240318': 1,
#  '20240323': 1,
#  '20240328': 1,
#  '20240329': 1,
#  '20240330': 1,
#  '20240331': 1,
#  '20240401': 1,
#  '20240402': 1,
#  '20240407': 1,
#  '20240408': 1,
#  '20240410': 1,
#  '20240411': 1,
#  '20240413': 1,
#  '20240414': 1,
#  '20240415': 1,
#  '20240416': 1,
#  '20240417': 1,
#  '20240418': 1,
#  '20240419': 1,
#  '20240420': 1,
#  '20240422': 1,
#  '20240423': 1,
#  '20240424': 1,
#  '20240427': 1,
#  '20240428': 1,
#  '20240501': 1,
#  '20240503': 1,
#  '20240504': 1,
#  '20240505': 1,
#  '20240506': 1,
#  '20240507': 1,
#  '20240509': 1,
#  '20240510': 1,
#  '20240512': 1,
#  '20240513': 1,
#  '20240514': 1,
#  '20240516': 1,
#  '20240527': 1,
#  '20240528': 1,
#  '20240529': 1,
#  '20240530': 1,
#  '20240531': 1,
#  '20240601': 1,
#  '20240602': 1,
#  '20240603': 1,
#  '20240604': 1,
#  '20240605': 1,
#  '20240607': 1,
#  '20240608': 1,
#  '20240609': 1,
#  '20240610': 1,
#  '20240611': 1,
#  '20240612': 1,
#  '20240613': 1,
#  '20240614': 1,
#  ...}

# %% [markdown]
# ## Streaks Format

# %%
streaks_df = pd.read_csv("./examples/streaks_example.csv")
streaks_df
# Out:
#                                 task_id       title          icon  \
# 0  01D26207-B0D5-4906-AC75-4D3606074A1E  Journaling  ic_pen_quill
# 1  01D26207-B0D5-4906-AC75-4D3606074A1E  Journaling  ic_pen_quill
# 2  01D26207-B0D5-4906-AC75-4D3606074A1E  Journaling  ic_pen_quill
#
#            entry_type  entry_date       entry_timestamp entry_timezone  \
# 0         missed_auto    20250911  2025-09-12T13:53:20Z  Europe/Berlin
# 1  completed_manually    20250912  2025-09-12T13:53:20Z  Europe/Berlin
# 2  completed_manually    20250913  2025-09-13T17:05:34Z  Europe/Berlin
#
#    quantity  page  notes
# 0       0.0     0    NaN
# 1       0.0     0    NaN
# 2       0.0     0    NaN

# %% [markdown]
# Header Format:
# - `task_id`: UUID per task/habit
# - `title`: Name of the habit
# - `icon`: Icon representing the habit (e.g., `ic_pen_quill`)
# - `entry_type`: Type of entry, currently known values are `completed_manually` and `missed_auto`
# - `entry_date`: Date of the task completion aka (where to render the checkmark/cross)
# - `entry_timestamp`: Timestamp of when the entry was recorded
# - `entry_timezone`: Timezone of the entry (e.g., `Europe/Berlin`)
# - `quantity`: Quantity associated with the entry, currently always `0.0`
# - `page`: Page number, I guess this must be [0-3]
# - `notes`: Additional notes
#
# Whats missing:
# - Target frequency and quantity per habit
#
# There is also a `*.streaks` file (json) that has more metadata but the property names are not self-explanatory.

# %%
streaks_df.columns
# Out:
# Index(['task_id', 'title', 'icon', 'entry_type', 'entry_date',
#        'entry_timestamp', 'entry_timezone', 'quantity', 'page', 'notes'],
#       dtype='object')

# %% [markdown]
# ## Conversion
#
# - new UUID per task and maybe a default icon?
# - we probably want `completed_manually` for all converted entries

# %%
for row in habits_df.itertuples():
    print(row.name)
# Out:
# 01. Film/Series/Game
# 02. Allergy
# 03. Write
# 04. Cutsie Book
# 05. VitD
# 07. Finance
# 08. Music
# 09. Read
# 10. Sport
# 11. NoX
# 12. Sex
# 13. NoCaff
# 13.1 Caff
# 14. VeggieDay
# 15. Photography/Edit
# 16. Take a walk and free the mind
# 17. Reflection/Personal Growth
# 19. Headache
# 20. Ibu
# 21. Alcohol

# %%
def habit_to_streak(df, name_remap: dict = {}):
    # Default values
    icon = "ic_pen_quill"
    entry_type = "completed_manually"
    entry_timestamp = datetime.now(timezone.utc).strftime("%Y-%m-%dT%H:%M:%SZ")
    entry_timezone = timezone.utc
    page = 0  # Streaks automatically overflows to the next page
    note = "imported"

    output = []
    for row in tqdm.tqdm(df.itertuples()):
        task_id = str(uuid4()).upper()
        title = name_remap.get(row.name, row.name)

        for date, quantity in (
            entry.split(":") for entry in sorted(row.date_quantity.split("-"))
        ):
            output.append(
                {
                    "task_id": task_id,
                    "title": title,
                    "icon": icon,
                    "entry_type": entry_type,
                    "entry_date": date,
                    "entry_timestamp": entry_timestamp,
                    "entry_timezone": entry_timezone,
                    "quantity": quantity,
                    "page": page,
                    "notes": note,
                }
            )

    return pd.DataFrame(output)

# %%
remap = {name: name.split(" ", 1)[1] for name in habits_df["name"].to_list()}

converted_df = habit_to_streak(habits_df, remap)
# Out:
# 20it [00:00, 2060.68it/s]

# %%
remap
# Out:
# {'01. Film/Series/Game': 'Film/Series/Game',
#  '02. Allergy': 'Allergy',
#  '03. Write': 'Write',
#  '04. Cutsie Book': 'Cutsie Book',
#  '05. VitD': 'VitD',
#  '07. Finance': 'Finance',
#  '08. Music': 'Music',
#  '09. Read': 'Read',
#  '10. Sport': 'Sport',
#  '11. NoX': 'NoX',
#  '12. Sex': 'Sex',
#  '13. NoCaff': 'NoCaff',
#  '13.1 Caff': 'Caff',
#  '14. VeggieDay': 'VeggieDay',
#  '15. Photography/Edit': 'Photography/Edit',
#  '16. Take a walk and free the mind': 'Take a walk and free the mind',
#  '17. Reflection/Personal Growth': 'Reflection/Personal Growth',
#  '19. Headache': 'Headache',
#  '20. Ibu': 'Ibu',
#  '21. Alcohol': 'Alcohol'}

# %%
# converted_df.to_csv("output_for_streaks.csv")
