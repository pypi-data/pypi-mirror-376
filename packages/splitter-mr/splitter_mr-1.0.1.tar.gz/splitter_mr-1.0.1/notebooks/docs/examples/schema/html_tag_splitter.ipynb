# %% [markdown]
# # **Example**: Splitting an HTML Table into Chunks with `HTMLTagSplitter`
#
# As an example, we will use a dataset of donuts in HTML table format (see [reference dataset](https://github.com/andreshere00/Splitter_MR/blob/main/https://raw.githubusercontent.com/andreshere00/Splitter_MR/refs/heads/main/data/sweet_list.html)).
# The goal is to split the table into groups of rows so that each chunk contains as many `<tr>` elements as possible, while not exceeding a maximum number of characters per chunk.
#
# ![HTML Tag examples](https://www.tutorialspoint.com/html/images/html_basic_tags.jpg)
#
# ---
#
# ## Step 1: Read the HTML Document
#
# We will use the [`VanillaReader`](https://andreshere00.github.io/Splitter_MR/api_reference/reader/#vanillareader) to load our HTML table.

# %%
from splitter_mr.reader import VanillaReader

reader = VanillaReader()  # you can use the argument html_to_markdown to transform the table directly to markdown format.

# You can provide a local path or a URL to your HTML file
url = "https://raw.githubusercontent.com/andreshere00/Splitter_MR/refs/heads/main/data/sweet_list.html"
reader_output = reader.read(url)

# %% [markdown]
# The [`reader_output`](https://andreshere00.github.io/Splitter_MR/api_reference/reader/#output-format) object contains the raw HTML and metadata.

# %%
print(reader_output.model_dump_json(indent=4))
# Out:
# {
#     "text": "<table border=\"1\" cellpadding=\"4\" cellspacing=\"0\">\n    <thead>\n      <tr>\n        <th>id</th>\n        <th>type</th>\n        <th>name</th>\n        <th>batter</th>\n        <th>topping</th>\n      </tr>\n    </thead>\n    <tbody>\n      <tr><td>0001</td><td>donut</td><td>Cake</td><td>Regular</td><td>None</td></tr>\n      <tr><td>0001</td><td>donut</td><td>Cake</td><td>Regular</td><td>Glazed</td></tr>\n      <tr><td>0001</td><td>donut</td><td>Cake</td><td>Regular</td><td>Sugar</td></tr>\n      <tr><td>0001</td><td>donut</td><td>Cake</td><td>Regular</td><td>Powdered Sugar</td></tr>\n      <tr><td>0001</td><td>donut</td><td>Cake</td><td>Regular</td><td>Chocolate with Sprinkles</td></tr>\n      <tr><td>0001</td><td>donut</td><td>Cake</td><td>Regular</td><td>Chocolate</td></tr>\n      <tr><td>0001</td><td>donut</td><td>Cake</td><td>Regular</td><td>Maple</td></tr>\n      <tr><td>0001</td><td>donut</td><td>Cake</td><td>Chocolate</td><td>None</td></tr>\n      <tr><td>0001</td><td>donut</td><td>Cake</td><td>Chocolate</td><td>Glazed</td></tr>\n      <tr><td>0001</td><td>donut</td><td>Cake</td><td>Chocolate</td><td>Sugar</td></tr>\n      <tr><td>0001</td><td>donut</td><td>Cake</td><td>Chocolate</td><td>Powdered Sugar</td></tr>\n      <tr><td>0001</td><td>donut</td><td>Cake</td><td>Chocolate</td><td>Chocolate with Sprinkles</td></tr>\n      <tr><td>0001</td><td>donut</td><td>Cake</td><td>Chocolate</td><td>Chocolate</td></tr>\n      <tr><td>0001</td><td>donut</td><td>Cake</td><td>Chocolate</td><td>Maple</td></tr>\n      <tr><td>0001</td><td>donut</td><td>Cake</td><td>Blueberry</td><td>None</td></tr>\n      <tr><td>0001</td><td>donut</td><td>Cake</td><td>Blueberry</td><td>Glazed</td></tr>\n      <tr><td>0001</td><td>donut</td><td>Cake</td><td>Blueberry</td><td>Sugar</td></tr>\n      <tr><td>0001</td><td>donut</td><td>Cake</td><td>Blueberry</td><td>Powdered Sugar</td></tr>\n      <tr><td>0001</td><td>donut</td><td>Cake</td><td>Blueberry</td><td>Chocolate with Sprinkles</td></tr>\n      <tr><td>0001</td><td>donut</td><td>Cake</td><td>Blueberry</td><td>Chocolate</td></tr>\n      <tr><td>0001</td><td>donut</td><td>Cake</td><td>Blueberry</td><td>Maple</td></tr>\n      <tr><td>0001</td><td>donut</td><td>Cake</td><td>Devil's Food</td><td>None</td></tr>\n      <tr><td>0001</td><td>donut</td><td>Cake</td><td>Devil's Food</td><td>Glazed</td></tr>\n      <tr><td>0001</td><td>donut</td><td>Cake</td><td>Devil's Food</td><td>Sugar</td></tr>\n      <tr><td>0001</td><td>donut</td><td>Cake</td><td>Devil's Food</td><td>Powdered Sugar</td></tr>\n      <tr><td>0001</td><td>donut</td><td>Cake</td><td>Devil's Food</td><td>Chocolate with Sprinkles</td></tr>\n      <tr><td>0001</td><td>donut</td><td>Cake</td><td>Devil's Food</td><td>Chocolate</td></tr>\n      <tr><td>0001</td><td>donut</td><td>Cake</td><td>Devil's Food</td><td>Maple</td></tr>\n      <tr><td>0002</td><td>donut</td><td>Raised</td><td>Regular</td><td>None</td></tr>\n      <tr><td>0002</td><td>donut</td><td>Raised</td><td>Regular</td><td>Glazed</td></tr>\n      <tr><td>0002</td><td>donut</td><td>Raised</td><td>Regular</td><td>Sugar</td></tr>\n      <tr><td>0002</td><td>donut</td><td>Raised</td><td>Regular</td><td>Chocolate</td></tr>\n      <tr><td>0002</td><td>donut</td><td>Raised</td><td>Regular</td><td>Maple</td></tr>\n      <tr><td>0003</td><td>donut</td><td>Old Fashioned</td><td>Regular</td><td>None</td></tr>\n      <tr><td>0003</td><td>donut</td><td>Old Fashioned</td><td>Regular</td><td>Glazed</td></tr>\n      <tr><td>0003</td><td>donut</td><td>Old Fashioned</td><td>Regular</td><td>Chocolate</td></tr>\n      <tr><td>0003</td><td>donut</td><td>Old Fashioned</td><td>Regular</td><td>Maple</td></tr>\n      <tr><td>0003</td><td>donut</td><td>Old Fashioned</td><td>Chocolate</td><td>None</td></tr>\n      <tr><td>0003</td><td>donut</td><td>Old Fashioned</td><td>Chocolate</td><td>Glazed</td></tr>\n      <tr><td>0003</td><td>donut</td><td>Old Fashioned</td><td>Chocolate</td><td>Choco ...
#     "document_name": "sweet_list.html",
#     "document_path": "https://raw.githubusercontent.com/andreshere00/Splitter_MR/refs/heads/main/data/sweet_list.html",
#     "document_id": "413c5f15-c7bc-407f-862e-9f392aa46c95",
#     "conversion_method": "html",
#     "reader_method": "vanilla",
#     "ocr_method": null,
#     "page_placeholder": null,
#     "metadata": {}
# }

# %% [markdown]
# To see the HTML text:

# %%
print(reader_output.text)
# Out:
# <table border="1" cellpadding="4" cellspacing="0">
#     <thead>
#       <tr>
#         <th>id</th>
#         <th>type</th>
#         <th>name</th>
#         <th>batter</th>
#         <th>topping</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr><td>0001</td><td>donut</td><td>Cake</td><td>Regular</td><td>None</td></tr>
#       <tr><td>0001</td><td>donut</td><td>Cake</td><td>Regular</td><td>Glazed</td></tr>
#       <tr><td>0001</td><td>donut</td><td>Cake</td><td>Regular</td><td>Sugar</td></tr>
#       <tr><td>0001</td><td>donut</td><td>Cake</td><td>Regular</td><td>Powdered Sugar</td></tr>
#       <tr><td>0001</td><td>donut</td><td>Cake</td><td>Regular</td><td>Chocolate with Sprinkles</td></tr>
#       <tr><td>0001</td><td>donut</td><td>Cake</td><td>Regular</td><td>Chocolate</td></tr>
#       <tr><td>0001</td><td>donut</td><td>Cake</td><td>Regular</td><td>Maple</td></tr>
#       <tr><td>0001</td><td>donut</td><td>Cake</td><td>Chocolate</td><td>None</td></tr>
#       <tr><td>0001</td><td>donut</td><td>Cake</td><td>Chocolate</td><td>Glazed</td></tr>
#       <tr><td>0001</td><td>donut</td><td>Cake</td><td>Chocolate</td><td>Sugar</td></tr>
#       <tr><td>0001</td><td>donut</td><td>Cake</td><td>Chocolate</td><td>Powdered Sugar</td></tr>
#       <tr><td>0001</td><td>donut</td><td>Cake</td><td>Chocolate</td><td>Chocolate with Sprinkles</td></tr>
#       <tr><td>0001</td><td>donut</td><td>Cake</td><td>Chocolate</td><td>Chocolate</td></tr>
#       <tr><td>0001</td><td>donut</td><td>Cake</td><td>Chocolate</td><td>Maple</td></tr>
#       <tr><td>0001</td><td>donut</td><td>Cake</td><td>Blueberry</td><td>None</td></tr>
#       <tr><td>0001</td><td>donut</td><td>Cake</td><td>Blueberry</td><td>Glazed</td></tr>
#       <tr><td>0001</td><td>donut</td><td>Cake</td><td>Blueberry</td><td>Sugar</td></tr>
#       <tr><td>0001</td><td>donut</td><td>Cake</td><td>Blueberry</td><td>Powdered Sugar</td></tr>
#       <tr><td>0001</td><td>donut</td><td>Cake</td><td>Blueberry</td><td>Chocolate with Sprinkles</td></tr>
#       <tr><td>0001</td><td>donut</td><td>Cake</td><td>Blueberry</td><td>Chocolate</td></tr>
#       <tr><td>0001</td><td>donut</td><td>Cake</td><td>Blueberry</td><td>Maple</td></tr>
#       <tr><td>0001</td><td>donut</td><td>Cake</td><td>Devil's Food</td><td>None</td></tr>
#       <tr><td>0001</td><td>donut</td><td>Cake</td><td>Devil's Food</td><td>Glazed</td></tr>
#       <tr><td>0001</td><td>donut</td><td>Cake</td><td>Devil's Food</td><td>Sugar</td></tr>
#       <tr><td>0001</td><td>donut</td><td>Cake</td><td>Devil's Food</td><td>Powdered Sugar</td></tr>
#       <tr><td>0001</td><td>donut</td><td>Cake</td><td>Devil's Food</td><td>Chocolate with Sprinkles</td></tr>
#       <tr><td>0001</td><td>donut</td><td>Cake</td><td>Devil's Food</td><td>Chocolate</td></tr>
#       <tr><td>0001</td><td>donut</td><td>Cake</td><td>Devil's Food</td><td>Maple</td></tr>
#       <tr><td>0002</td><td>donut</td><td>Raised</td><td>Regular</td><td>None</td></tr>
#       <tr><td>0002</td><td>donut</td><td>Raised</td><td>Regular</td><td>Glazed</td></tr>
#       <tr><td>0002</td><td>donut</td><td>Raised</td><td>Regular</td><td>Sugar</td></tr>
#       <tr><td>0002</td><td>donut</td><td>Raised</td><td>Regular</td><td>Chocolate</td></tr>
#       <tr><td>0002</td><td>donut</td><td>Raised</td><td>Regular</td><td>Maple</td></tr>
#       <tr><td>0003</td><td>donut</td><td>Old Fashioned</td><td>Regular</td><td>None</td></tr>
#       <tr><td>0003</td><td>donut</td><td>Old Fashioned</td><td>Regular</td><td>Glazed</td></tr>
#       <tr><td>0003</td><td>donut</td><td>Old Fashioned</td><td>Regular</td><td>Chocolate</td></tr>
#       <tr><td>0003</td><td>donut</td><td>Old Fashioned</td><td>Regular</td><td>Maple</td></tr>
#       <tr><td>0003</td><td>donut</td><td>Old Fashioned</td><td>Chocolate</td><td>None</td></tr>
#       <tr><td>0003</td><td>donut</td><td>Old Fashioned</td><td>Chocolate</td><td>Glazed</td></tr>
#       <tr><td>0003</td><td>donut</td><td>Old Fashioned</td><td>Chocolate</td><td>Chocolate</td></tr>
#       <tr><td>0003</td><td>donut</td><td>Old Fashioned</td><td>Chocolate</td><td>Maple</td></tr>
#       <tr><td>0004</td><td>bar</td><td>Bar</td><td>Regular</td><td>Chocolate</td></tr>
#       <tr><td>0004</td><td>bar</td><td>Bar</td><td>Regular</td><td>Maple</td></tr>
#       <tr><td>0005</td><td>twist</td><td>Twist</td><td>Regular</td><td>Glazed</td></tr>
#       <tr><td>0005</td><td>twist</td><td>Twist</td><td>Regular</td><td>Sugar</td></tr>
#       <tr><td>0006</td><td>filled</td><td>Filled</td><td>Regular</td><td>Glazed</td></tr>
#       <tr><td>0006</td><td>filled</td><td>Filled</td><td>Regular</td><td>Powdered Sugar</td></tr>
#       <tr><td>0006</td><td>filled</td><td>Filled</td><td>Regular</td><td>Chocolate</td></tr>
#       <tr><td>0006</td><td>filled</td><td>Filled</td><td>Regular</td><td>Maple</td></tr>
#     </tbody>
#   </table>

# %% [markdown]
# This table can be interpretated in markdown format as:
#
# |id|type|name|batter|topping|
# |--- |--- |--- |--- |--- |
# |0001|donut|Cake|Regular|None|
# |0001|donut|Cake|Regular|Glazed|
# |0001|donut|Cake|Regular|Sugar|
# |...|...|...|...|...|
# |0006|filled|Filled|Regular|Chocolate|
# |0006|filled|Filled|Regular|Maple|
#
# Note that you can parse directly this table in VanillaReader using the keyword argument `html_to_markdown=True`. Refer to the [class documentation](https://andreshere00.github.io/Splitter_MR/api_reference/reader/#vanillareader).
#
#
# ---
#
# ## Step 2: Chunk the HTML Table Using `HTMLTagSplitter`
#
# To split the table into groups of rows, instantiate the [**`HTMLTagSplitter`**](https://andreshere00.github.io/Splitter_MR/api_reference/splitter/#htmltagsplitter) with the desired tag (in this case, `"tr"` for table rows) and a chunk size in characters.

# %%
from splitter_mr.splitter import HTMLTagSplitter

# Set chunk_size to the max number of characters you want per chunk
splitter = HTMLTagSplitter(chunk_size=400, tag="tr")
splitter_output = splitter.split(reader_output)
print(splitter_output.model_dump_json(indent=4))
# Out:
# {
#     "chunks": [
#         "| id | type | name | batter | topping |\n| --- | --- | --- | --- | --- |\n| 0001 | donut | Cake | Regular | None |\n| 0001 | donut | Cake | Regular | Glazed |",
#         "| id | type | name | batter | topping |\n| --- | --- | --- | --- | --- |\n| 0001 | donut | Cake | Regular | Sugar |\n| 0001 | donut | Cake | Regular | Powdered Sugar |",
#         "| id | type | name | batter | topping |\n| --- | --- | --- | --- | --- |\n| 0001 | donut | Cake | Regular | Chocolate with Sprinkles |\n| 0001 | donut | Cake | Regular | Chocolate |",
#         "| id | type | name | batter | topping |\n| --- | --- | --- | --- | --- |\n| 0001 | donut | Cake | Regular | Maple |\n| 0001 | donut | Cake | Chocolate | None |",
#         "| id | type | name | batter | topping |\n| --- | --- | --- | --- | --- |\n| 0001 | donut | Cake | Chocolate | Glazed |\n| 0001 | donut | Cake | Chocolate | Sugar |",
#         "| id | type | name | batter | topping |\n| --- | --- | --- | --- | --- |\n| 0001 | donut | Cake | Chocolate | Powdered Sugar |\n| 0001 | donut | Cake | Chocolate | Chocolate with Sprinkles |",
#         "| id | type | name | batter | topping |\n| --- | --- | --- | --- | --- |\n| 0001 | donut | Cake | Chocolate | Chocolate |\n| 0001 | donut | Cake | Chocolate | Maple |",
#         "| id | type | name | batter | topping |\n| --- | --- | --- | --- | --- |\n| 0001 | donut | Cake | Blueberry | None |\n| 0001 | donut | Cake | Blueberry | Glazed |",
#         "| id | type | name | batter | topping |\n| --- | --- | --- | --- | --- |\n| 0001 | donut | Cake | Blueberry | Sugar |\n| 0001 | donut | Cake | Blueberry | Powdered Sugar |",
#         "| id | type | name | batter | topping |\n| --- | --- | --- | --- | --- |\n| 0001 | donut | Cake | Blueberry | Chocolate with Sprinkles |\n| 0001 | donut | Cake | Blueberry | Chocolate |",
#         "| id | type | name | batter | topping |\n| --- | --- | --- | --- | --- |\n| 0001 | donut | Cake | Blueberry | Maple |\n| 0001 | donut | Cake | Devil's Food | None |",
#         "| id | type | name | batter | topping |\n| --- | --- | --- | --- | --- |\n| 0001 | donut | Cake | Devil's Food | Glazed |\n| 0001 | donut | Cake | Devil's Food | Sugar |",
#         "| id | type | name | batter | topping |\n| --- | --- | --- | --- | --- |\n| 0001 | donut | Cake | Devil's Food | Powdered Sugar |\n| 0001 | donut | Cake | Devil's Food | Chocolate with Sprinkles |",
#         "| id | type | name | batter | topping |\n| --- | --- | --- | --- | --- |\n| 0001 | donut | Cake | Devil's Food | Chocolate |\n| 0001 | donut | Cake | Devil's Food | Maple |",
#         "| id | type | name | batter | topping |\n| --- | --- | --- | --- | --- |\n| 0002 | donut | Raised | Regular | None |\n| 0002 | donut | Raised | Regular | Glazed |",
#         "| id | type | name | batter | topping |\n| --- | --- | --- | --- | --- |\n| 0002 | donut | Raised | Regular | Sugar |\n| 0002 | donut | Raised | Regular | Chocolate |",
#         "| id | type | name | batter | topping |\n| --- | --- | --- | --- | --- |\n| 0002 | donut | Raised | Regular | Maple |\n| 0003 | donut | Old Fashioned | Regular | None |",
#         "| id | type | name | batter | topping |\n| --- | --- | --- | --- | --- |\n| 0003 | donut | Old Fashioned | Regular | Glazed |\n| 0003 | donut | Old Fashioned | Regular | Chocolate |",
#         "| id | type | name | batter | topping |\n| --- | --- | --- | --- | --- |\n| 0003 | donut | Old Fashioned | Regular | Maple |\n| 0003 | donut | Old Fashioned | Chocolate | None |",
#         "| id | type | name | batter | topping |\n| --- | --- | --- | --- | --- |\n| 0003 | donut | Old Fashioned | Chocolate | Glazed |\n| 0003 | donut | Old Fashioned | Chocolate | Chocolate |",
#         "| id | type | name | batter | topping |\n| --- | --- | --- | --- | --- |\n| 0003 | donut | Old Fashioned | Chocolate | Maple |\n| 0004 | bar | Bar | Regular | Chocolate |",
#         "| id | type | name | batter | topping |\n| --- | --- | --- | --- | --- |\n| 0004 | bar | Bar | Regular | Maple |\n| 0005 | twist | Twist | Regular | Glazed |",
#         "| id | type | name | batter | topping |\n| --- | --- | --- | --- | --- |\n| 0005 | twist | Twist | Regular | Sugar |\n| 0006 | filled | Filled | Regular | Glazed |",
#         "| id | type | name | batter | topping |\n| --- | --- | --- | --- | --- |\n| 0006 | filled | Filled | Regular | Powdered Sugar |\n| 0006 | filled | Filled | Regular | Chocolate |",
#         "| id | type | name | batter | topping |\n| --- | --- | --- | --- | --- |\n| 0006 | filled | Filled | Regular | Maple |"
#     ],
#     "chunk_id": [
#         "69315227-8b20-4c93-8621-6568507b3c27",
#         "30c68f95-e102-4cf4-b1de-4ba7e32c77ec",
#         "a562eef8-8cb2-4ee6-88f9-8d48adfd073e",
#         "0bce2ba2-ebe4-4b48-9c09-43c5128a20b4",
#         "2367fd80-655a-410c-bf01-0d7839e65d2d",
#         "12e758d6-581d-49f6-ba08-d67b213f3513",
#         "6f69444a-7254-47cb-b7d2-0b386eff1c7e",
#         "f13a7d5b-72b8-44f1-9c87-03e2f6606333",
#         "09b24e0d-04f0-40e9-8956-658536b26d80",
#         "83de5675-db4c-4b43-a68e-6f35fcd7496a",
#         "8c79e938-c93a-4766-948b-893d5c53ed24",
#         "69f3f0c0-948a-431e-9fc0-591087c01eb2",
#         "49256a08-3e86-4ddb-bd37-bdce98c2ec9d",
#         "560e8bfa-20c3-4855-b34f-9f94bc9c0135",
#         "191a8813-2920-454b-8fae-1d8d9ea545ea",
#         "6361e734-3df5-4da6-8edd-f91556d16a4f",
#         "15ce18f6-9a90-4c52-9c0b-5537d2ac1c4f",
#         "0904e6b7-ad91-4f22-9f34-826bc3eaf27a",
#         "22381e29-e7d6-4c81-aefd-000246f19b60",
#         "55d94458-bc13-4a2d-a7c0-08b9cfa55845",
#         "7205c24f-a8e8-43f0-af13-b045d0ba0cfa",
#         "e295c669-6196-44ac-9d89-5b7c0400fb8e",
#         "c30a0890-96a3-4b8f-872f-c959206c9942",
#         "2b0ffb9e-82ce-405c-b071-0d4cd77aff99",
#         "3e8fca82-917f-40a9-8d46-0ca350f181ba"
#     ],
#     "document_name": "sweet_list.html",
#     "document_path": "https://raw.githubusercontent.com/andreshere00/Splitter_MR/refs/heads/main/data/sweet_list.html",
#     "document_id": "413c5f15-c7bc-407f-862e-9f392aa46c95",
#     "conversion_method": "html",
#     "reader_method": "vanilla",
#     "ocr_method": null,
#     "split_method": "html_tag_splitter",
#     "split_params": {
#         "chunk_size": 400,
#         "tag": "table",
#         "batch": true,
#         "to_markdown": true
#     },
#     "metadata": {}
# }

# %% [markdown]
# To visualize each chunk, simply iterate through them:

# %%
for idx, chunk in enumerate(splitter_output.chunks):
    print("=" * 40 + f" Chunk {idx + 1} " + "=" * 40 + "\n" + chunk + "\n")
# Out:
# ======================================== Chunk 1 ========================================
# | id | type | name | batter | topping |
# | --- | --- | --- | --- | --- |
# | 0001 | donut | Cake | Regular | None |
# | 0001 | donut | Cake | Regular | Glazed |
#
# ======================================== Chunk 2 ========================================
# | id | type | name | batter | topping |
# | --- | --- | --- | --- | --- |
# | 0001 | donut | Cake | Regular | Sugar |
# | 0001 | donut | Cake | Regular | Powdered Sugar |
#
# ======================================== Chunk 3 ========================================
# | id | type | name | batter | topping |
# | --- | --- | --- | --- | --- |
# | 0001 | donut | Cake | Regular | Chocolate with Sprinkles |
# | 0001 | donut | Cake | Regular | Chocolate |
#
# ======================================== Chunk 4 ========================================
# | id | type | name | batter | topping |
# | --- | --- | --- | --- | --- |
# | 0001 | donut | Cake | Regular | Maple |
# | 0001 | donut | Cake | Chocolate | None |
#
# ======================================== Chunk 5 ========================================
# | id | type | name | batter | topping |
# | --- | --- | --- | --- | --- |
# | 0001 | donut | Cake | Chocolate | Glazed |
# | 0001 | donut | Cake | Chocolate | Sugar |
#
# ======================================== Chunk 6 ========================================
# | id | type | name | batter | topping |
# | --- | --- | --- | --- | --- |
# | 0001 | donut | Cake | Chocolate | Powdered Sugar |
# | 0001 | donut | Cake | Chocolate | Chocolate with Sprinkles |
#
# ======================================== Chunk 7 ========================================
# | id | type | name | batter | topping |
# | --- | --- | --- | --- | --- |
# | 0001 | donut | Cake | Chocolate | Chocolate |
# | 0001 | donut | Cake | Chocolate | Maple |
#
# ======================================== Chunk 8 ========================================
# | id | type | name | batter | topping |
# | --- | --- | --- | --- | --- |
# | 0001 | donut | Cake | Blueberry | None |
# | 0001 | donut | Cake | Blueberry | Glazed |
#
# ======================================== Chunk 9 ========================================
# | id | type | name | batter | topping |
# | --- | --- | --- | --- | --- |
# | 0001 | donut | Cake | Blueberry | Sugar |
# | 0001 | donut | Cake | Blueberry | Powdered Sugar |
#
# ======================================== Chunk 10 ========================================
# | id | type | name | batter | topping |
# | --- | --- | --- | --- | --- |
# | 0001 | donut | Cake | Blueberry | Chocolate with Sprinkles |
# | 0001 | donut | Cake | Blueberry | Chocolate |
#
# ======================================== Chunk 11 ========================================
# | id | type | name | batter | topping |
# | --- | --- | --- | --- | --- |
# | 0001 | donut | Cake | Blueberry | Maple |
# | 0001 | donut | Cake | Devil's Food | None |
#
# ======================================== Chunk 12 ========================================
# | id | type | name | batter | topping |
# | --- | --- | --- | --- | --- |
# | 0001 | donut | Cake | Devil's Food | Glazed |
# | 0001 | donut | Cake | Devil's Food | Sugar |
#
# ======================================== Chunk 13 ========================================
# | id | type | name | batter | topping |
# | --- | --- | --- | --- | --- |
# | 0001 | donut | Cake | Devil's Food | Powdered Sugar |
# | 0001 | donut | Cake | Devil's Food | Chocolate with Sprinkles |
#
# ======================================== Chunk 14 ========================================
# | id | type | name | batter | topping |
# | --- | --- | --- | --- | --- |
# | 0001 | donut | Cake | Devil's Food | Chocolate |
# | 0001 | donut | Cake | Devil's Food | Maple |
#
# ======================================== Chunk 15 ========================================
# | id | type | name | batter | topping |
# | --- | --- | --- | --- | --- |
# | 0002 | donut | Raised | Regular | None |
# | 0002 | donut | Raised | Regular | Glazed |
#
# ======================================== Chunk 16 ========================================
# | id | type | name | batter | topping |
# | --- | --- | --- | --- | --- |
# | 0002 | donut | Raised | Regular | Sugar |
# | 0002 | donut | Raised | Regular | Chocolate |
#
# ======================================== Chunk 17 ========================================
# | id | type | name | batter | topping |
# | --- | --- | --- | --- | --- |
# | 0002 | donut | Raised | Regular | Maple |
# | 0003 | donut | Old Fashioned | Regular | None |
#
# ======================================== Chunk 18 ========================================
# | id | type | name | batter | topping |
# | --- | --- | --- | --- | --- |
# | 0003 | donut | Old Fashioned | Regular | Glazed |
# | 0003 | donut | Old Fashioned | Regular | Chocolate |
#
# ======================================== Chunk 19 ========================================
# | id | type | name | batter | topping |
# | --- | --- | --- | --- | --- |
# | 0003 | donut | Old Fashioned | Regular | Maple |
# | 0003 | donut | Old Fashioned | Chocolate | None |
#
# ======================================== Chunk 20 ========================================
# | id | type | name | batter | topping |
# | --- | --- | --- | --- | --- |
# | 0003 | donut | Old Fashioned | Chocolate | Glazed |
# | 0003 | donut | Old Fashioned | Chocolate | Chocolate |
#
# ======================================== Chunk 21 ========================================
# | id | type | name | batter | topping |
# | --- | --- | --- | --- | --- |
# | 0003 | donut | Old Fashioned | Chocolate | Maple |
# | 0004 | bar | Bar | Regular | Chocolate |
#
# ======================================== Chunk 22 ========================================
# | id | type | name | batter | topping |
# | --- | --- | --- | --- | --- |
# | 0004 | bar | Bar | Regular | Maple |
# | 0005 | twist | Twist | Regular | Glazed |
#
# ======================================== Chunk 23 ========================================
# | id | type | name | batter | topping |
# | --- | --- | --- | --- | --- |
# | 0005 | twist | Twist | Regular | Sugar |
# | 0006 | filled | Filled | Regular | Glazed |
#
# ======================================== Chunk 24 ========================================
# | id | type | name | batter | topping |
# | --- | --- | --- | --- | --- |
# | 0006 | filled | Filled | Regular | Powdered Sugar |
# | 0006 | filled | Filled | Regular | Chocolate |
#
# ======================================== Chunk 25 ========================================
# | id | type | name | batter | topping |
# | --- | --- | --- | --- | --- |
# | 0006 | filled | Filled | Regular | Maple |

# %% [markdown]
# By default the output will be chunks with a valid markdown format. In case that needed, you can directly give the results in HTML format using the argument `to_markdown=False`. Refer to the [class documentation](https://andreshere00.github.io/Splitter_MR/api_reference/splitter/#htmltagsplitter).

# %% [markdown]
# **Chunk 1:**
#
# | id   | type  | name | batter  | topping |
# |-------|-------|-------|---------|---------|
# | 0001  | donut | Cake  | Regular | None    |
# | 0001  | donut | Cake  | Regular | Glazed  |
# | 0001  | donut | Cake  | Regular | Sugar   |
#
# **Chunk 2:**
#
# | id   | type  | name | batter  | topping |
# |-------|-------|-------|---------|---------|
# | 0001  | donut | Cake  | Regular | Powdered Sugar          |
# | 0001  | donut | Cake  | Regular | Chocolate with Sprinkles|
# | 0001  | donut | Cake  | Regular | Chocolate               |
# | 0001  | donut | Cake  | Regular | Maple                   |
#
# **And that's it!** You can now flexibly chunk HTML tables for processing, annotation, or LLM ingestion.
#
# ---
#
# ## Complete Script
#
# ```python
# from splitter_mr.reader import VanillaReader
# from splitter_mr.splitter import HTMLTagSplitter
#
# # Step 1: Read the HTML file
# reader = VanillaReader()
# url = "https://raw.githubusercontent.com/andreshere00/Splitter_MR/refs/heads/main/data/sweet_list.html"  # Use your path or URL here
# reader_output = reader.read(url)
#
# print(reader_output.model_dump_json(indent=4))  # Visualize the ReaderOutput object
# print(reader_output.text)  # See the HTML content
#
# # Step 2: Split by group of <tr> tags, max 400 characters per chunk
# splitter = HTMLTagSplitter(chunk_size=400, tag="tr")
# splitter_output = splitter.split(reader_output)
#
# print(splitter_output.model_dump_json(indent=4))  # Print the SplitterOutput object
#
# # Step 3: Visualize each HTML chunk
# for idx, chunk in enumerate(splitter_output.chunks):
#     print("="*40 + f" Chunk {idx + 1} " + "="*40 + "\n" + chunk + "\n")
# ```
