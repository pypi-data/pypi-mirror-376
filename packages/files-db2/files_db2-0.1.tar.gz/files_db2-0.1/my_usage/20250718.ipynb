# %%
import main

# %%
db = main.create(r"C:\Users\rrrad\OneDrive - Education Vaud\Pictures\Camera Roll")
# Out:
# 100%|██████████| 3377/3377 [00:01<00:00, 2150.49it/s]

# %%
data = db("2025").ls().sort_values(by="name")

# %%
db.ls()
# Out:
#              name        size     n               ctime               mtime  \
# 1     desktop.ini         190     1 2025-03-15 18:05:09 2025-07-16 10:22:00
# 2            2025  3100545996  1551 2025-03-15 18:28:17 2025-07-18 08:13:44
# 1553         2024  6955339294  1825 2025-03-15 18:26:44 2025-03-15 18:28:17
#
#                    atime  level  nls
# 1    2025-07-18 08:42:58      1   -1
# 2    2025-07-18 08:44:27      1    7
# 1553 2025-07-18 08:44:27      1    9

# %%
import matplotlib.pyplot as plt

plt.plot(data["name"],data["size"])

# %%
plt.plot(data["name"],data["n"])
