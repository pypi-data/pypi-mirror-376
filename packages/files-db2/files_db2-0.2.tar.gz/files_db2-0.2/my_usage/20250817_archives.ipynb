# %%
import main
db = main.create(r"C:\Users\rrrad\OneDrive - Education Vaud")
# Out:
# 100%|██████████| 194476/194476 [00:48<00:00, 3981.62it/s]

# %%
db = db.sort_values("n", ascending=False)

# %%
archives = db(r"Documents\archives")
archives
# Out:
#                                                      name         size  \
# 68134                                                   .  18636742961
# 68408                                              coding   8582786374
# 98005                                          coding\Rpy   2492026141
# 70624                                       coding\Rpy-mc   1202086692
# 73486                            coding\Rpy-mc\BuildTools    513062185
# ...                                                   ...          ...
# 194441                            autres\aki-ravitoto.png      5301819
# 194442        autres\9ceb48714eeefc9389979e51fecd5f69.mpd         1769
# 194443                        autres\20230831_064145.jpeg       206801
# 194444                 autres\12_hommes_en_colere-4_0.pdf      5219988
# 170167  coding\photosL\photosBC\Papa\2018\08 August\21...           76
#
#              n               ctime               mtime               atime  \
# ...

# %%
coding = archives("coding")
coding
# Out:
#                                                      name        size       n  \
# 68408                                                   .  8582786374  120584
# 98005                                                 Rpy  2492026141   63556
# 70624                                              Rpy-mc  1202086692   27381
# 73486                                   Rpy-mc\BuildTools   513062185   24262
# 161804                                            photosL  4260308243   22202
# ...                                                   ...         ...     ...
# 188985  cmake-learn\build\.cmake\api\v1\reply\cmakeFil...        5716       1
# 188986  cmake-learn\build\.cmake\api\v1\reply\cache-v2...       32324       1
# 188989  cmake-learn\build\.cmake\api\v1\query\client-v...         144       1
# 188991                           blockparty\blockparty.py       13209       1
# 170167  photosL\photosBC\Papa\2018\08 August\21.08 at ...          76       1
#
# ...

# %%
Rpy = coding("Rpy")
Rpy
# Out:
#                                                      name        size      n  \
# 98005                                                   .  2492026141  63556
# 135081                               jupyter-dependencies   198395067  13151
# 135086                         jupyter-dependencies\.venv   198152511  13146
# 135681                     jupyter-dependencies\.venv\lib   175792600  12492
# 135682          jupyter-dependencies\.venv\lib\python3.12   175792600  12491
# ...                                                   ...         ...    ...
# 161557                        .venv-bye\bin\activate.fish        2199      1
# 161558                         .venv-bye\bin\activate.csh         919      1
# 161559   .venv-bye\bin\activate-global-python-argcomplete        5370      1
# 161560                             .venv-bye\bin\activate        1993      1
# 145858  jupyter-dependencies\.venv\lib\python3.12\site...           4      1
#
# ...

# %%
126311-24262-17438
# Out:
# 84611

# %%
db_archives = main.create(r"C:\Users\rrrad\OneDrive - Education Vaud\Documents\archives")
# Out:
#  77%|███████▋  | 54834/71459 [00:12<00:03, 4396.74it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 db_archives = main.create(r"C:\Users\rrrad\OneDrive - Education Vaud\Documents\archives")
#
# File c:\Users\rrrad\OneDrive - Education Vaud\Documents\coding\files-db\main.py:132, in FilesDatabase.create(cls, src, show_progression)
#     130 data={"name":[],"size":[],"n":[],"ctime":[],"mtime":[],"atime":[],"level":[], "nls":[]}
#     131 with tqdm(total=total,disable=not show_progression) as pbar:
# --> 132     _process("",src,0)
#     134 self=cls(cls(data)[::-1].reset_index(drop=True).astype(ASTYPE))
#     135 self._remove_blank_name()
#
# File c:\Users\rrrad\OneDrive - Education Vaud\Documents\coding\files-db\main.py:101, in FilesDatabase.create.<locals>._process(relpath, path, level)
#      99 ls = os.listdir(path)
#     100 for item in ls:
# ...
